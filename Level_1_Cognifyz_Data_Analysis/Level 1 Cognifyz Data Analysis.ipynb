# %% [markdown]
# # Cognifyz Technologies - Data Analysis Internship
# ## Level 1

# %% [markdown]
# ---
# ## Task 1 - Top Cuisines
# **Objective:** Determine the top 3 most common cuisines and calculate the percentage of restaurants serving each.

# %%
# Task 1 Analysis
# Out:
# Total Restaurants: 9551
#
# Top 3 Most Common Cuisines:
# 1. North Indian: 3960 restaurants (41.46%)
# 2. Chinese: 2735 restaurants (28.64%)
# 3. Fast Food: 1986 restaurants (20.79%)

# %% [markdown]
# ---
# ## Task 2 - City Analysis
# **Objective:** Identify the city with the highest number of restaurants, calculate average rating per city, and determine the city with the highest average rating.

# %%
# Task 2 Analysis
# Out:
# City with most restaurants: New Delhi (5473)
# City with highest avg rating (min 10 restaurants): London (4.54)
#
# Top 10 Cities:
#   New Delhi: 5473
#   Gurgaon: 1118
#   Noida: 1080
#   Faridabad: 251
#   Ghaziabad: 25
#   Ahmedabad: 21
#   Amritsar: 21
#   Bhubaneshwar: 21
#   Guwahati: 21
#   Lucknow: 21

# %% [markdown]
# ---
# ## Task 3 - Price Range Distribution
# **Objective:** Visualize the distribution of price ranges and calculate the percentage in each category.

# %%
# Task 3 Analysis
# Out:
# Price Range Distribution:
#   Range 1 (Low): 4444 restaurants (46.53%)
#   Range 2 (Medium): 3113 restaurants (32.59%)
#   Range 3 (High): 1408 restaurants (14.74%)
#   Range 4 (Very High): 586 restaurants (6.14%)

# %% [markdown]
# ---
# ## Task 4 - Online Delivery
# **Objective:** Determine the percentage of restaurants offering online delivery and compare average ratings.

# %%
# Task 4 Analysis
# Out:
# Online Delivery Availability:
#   No: 7100 restaurants (74.34%)
#   Yes: 2451 restaurants (25.66%)
#
# Avg Rating WITH delivery:    3.25
# Avg Rating WITHOUT delivery: 2.47
